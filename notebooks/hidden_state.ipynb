# %%
import numpy as np
import pandas as pd

# %%
# Menload dataset
file_path = "data/"
file_name = "Indonesian_Manually_Tagged_Corpus.tsv"
word_corpus = pd.read_table(file_path + file_name, names=['word', 'tag'])

# Mengambil 1000 data pertama dan lowercasing
word_corpus = word_corpus[:1000]
word_corpus['word'] = word_corpus['word'].str.lower()

# %%
# Membuat representasi tabel emission probability dari HMM

hidden_state = {}
for word in word_corpus['word']:
    # Jika word belum pernah ditemui maka akan digenerate
    # tagset berserta probabilitasnya
    if word not in hidden_state.keys():
        dataframe = word_corpus[word_corpus["word"].isin([word])]
        # Membuat dictionary berisi semua tagset dari sebauh word
        # pada korpus. Berserta jumlah kemunculan setiap tagsetnya
        tag_count = {}
        for tag in dataframe.tag:
            if tag not in tag_count.keys():
                tag_count[tag] = 1
            else:
                tag_count[tag] += 1
        total = 0
        # Mengubah jumlah kemunculan menjadi probabilitas
        tag_prob = {}
        for count in tag_count.values():
            total += count
        for tagset in tag_count.keys():
            tag_prob[tagset] = tag_count[tagset]/total
        hidden_state[word] = tag_prob
    else:
        # Jika word sudah pernah ditemui maka akan dilewati
        continue

# %%
hidden_state
# Out:
# {'kera': {'NN': 1.0},
#  'untuk': {'SC': 0.6875, 'IN': 0.3125},
#  'amankan': {'VB': 1.0},
#  'pesta olahraga': {'NN': 0.5, 'NNP': 0.5},
#  'pemerintah': {'NNP': 0.6666666666666666, 'NN': 0.3333333333333333},
#  'kota': {'NNP': 1.0},
#  'delhi': {'NNP': 1.0},
#  'mengerahkan': {'VB': 1.0},
#  'monyet': {'NN': 1.0},
#  'mengusir': {'VB': 1.0},
#  'monyet-monyet': {'NN': 1.0},
#  'lain': {'JJ': 1.0},
#  'yang': {'SC': 1.0},
#  'berbadan': {'VB': 1.0},
#  'lebih': {'RB': 1.0},
#  'kecil': {'JJ': 1.0},
#  'dari': {'IN': 1.0},
#  'arena': {'NN': 1.0},
#  'persemakmuran': {'NNP': 1.0},
#  '.': {'Z': 1.0},
#  'beberapa': {'CD': 1.0},
#  'laporan': {'NN': 1.0},
#  'menyebutkan': {'VB': 1.0},
#  'setidaknya': {'RB': 1.0},
#  '10': {'CD': 1.0},
#  'ditempatkan': {'VB': 1.0},
#  'di': {'IN': 1.0},
#  'luar': {'NN': 1.0},
#  'lomba': {'NN': 1.0},
#  'dan': {'CC': 1.0},
#  'pertandingan': {'NN': 1.0},
#  'ibukota': {'NNP': 1.0},
#  'india': {'NNP': 1.0},
#  'pemkot': {'NNP': 0.5, 'NN': 0.5},
#  'memiliki': {'VB': 1.0},
#  '28': {'CD': 1.0},
#  'berencana': {'VB': 1.0},
#  'mendatangkan': {'VB': 1.0},
#  'sejenis': {'NN': 1.0},
#  'negara bagian': {'NNP': 1.0},
#  'rajasthan': {'NNP': 1.0},
#  'jumlah': {'NN': 1.0},
#  'mencapai': {'VB': 1.0},
#  'ribuan': {'CD': 1.0},
#  ',': {'Z': 1.0},
#  'sebagian besar': {'NN': 1.0},
#  'berada': {'VB': 1.0},
#  'kantor-kantor': {'NN': 1.0},
#  'hewan': {'NN': 1.0},
#  'ini': {'PR': 1.0},
#  'dianggap': {'VB': 1.0},
#  'mengganggu': {'VB': 1.0},
#  'ketertiban': {'NN': 1.0},
#  'umum': {'JJ': 1.0},
#  'jenis': {'NN': 1.0},
#  'dikerahkan': {'VB': 1.0},
#  'besar': {'JJ': 1.0},
#  'berekor': {'VB': 1.0},
#  'panjang': {'JJ': 1.0},
#  'wajah': {'NN': 1.0},
#  'berwarna': {'VB': 1.0},
#  'hitam': {'JJ': 1.0},
#  'diikat': {'VB': 1.0},
#  'dengan': {'IN': 0.8333333333333334, 'SC': 0.16666666666666666},
#  'tali': {'NN': 1.0},
#  'pelatih': {'NN': 1.0},
#  'mengawasi': {'VB': 1.0},
#  'mereka': {'PRP': 1.0},
#  'akan': {'MD': 1.0},
#  'melepas': {'VB': 1.0},
#  'begitu': {'SC': 0.5, 'RB': 0.5},
#  'mendekat': {'VB': 1.0},
#  'kantor': {'NNP': 0.5, 'NN': 0.5},
#  'berita': {'NNP': 1.0},
#  'afp': {'NNP': 1.0},
#  'melaporkan': {'VB': 1.0},
#  'stadion': {'NN': 1.0},
#  'tinju': {'NN': 1.0},
#  'hockey': {'FW': 1.0},
#  'mendapatkan': {'VB': 1.0},
#  'perhatian': {'NN': 1.0},
#  'khusus': {'JJ': 1.0},
#  'karena': {'SC': 1.0},
#  'sering': {'RB': 1.0},
#  'diserbu': {'VB': 1.0},
#  'dua': {'CD': 1.0},
#  'serbuan': {'NN': 1.0},
#  '\tz\r\nmonyet\tnn\r\nbesar\tjj\r\nakan\tmd\r\ndikerahkan\tvb\r\ndi\tin\r\ndua\tcd\r\nstadion\tnn\r\ntersebut\tpr\r\nuntuk\tsc\r\nmengusir\tvb\r\nserbuan\tnn\r\nmonyet\tnn\r\nkecil\tjj\r\n,\tz\r\n': {'Z': 1.0},
#  'kata': {'VB': 1.0},
#  'devender': {'NNP': 1.0},
#  'prasad': {'NNP': 1.0},
#  'pejabat': {'NN': 1.0},
#  'kepada': {'IN': 1.0},
#  'kantor berita': {'NNP': 1.0},
#  'selama': {'IN': 1.0},
#  'bertahun-tahun': {'CD': 1.0},
#  'warga': {'NN': 1.0},
#  'binatang': {'NN': 1.0},
#  'menaiki': {'VB': 1.0},
#  'kereta': {'NN': 1.0},
#  'metro': {'NN': 1.0},
#  'bahkan': {'RB': 1.0},
#  'berkeliaran': {'VB': 1.0},
#  'kompleks': {'NN': 1.0},
#  'gedung': {'NN': 1.0},
#  'parlemen': {'NN': 1.0},
#  'belum': {'NEG': 1.0},
#  'lama': {'JJ': 1.0},
#  'kawanan': {'NN': 1.0},
#  'menyerbu': {'VB': 1.0},
#  'perdana menteri': {'NN': 1.0},
#  'departemen': {'NN': 1.0},
#  'pertahanan': {'NN': 1.0},
#  'tidak': {'NEG': 1.0},
#  'bisa': {'MD': 1.0},
#  'dibunuh': {'VB': 1.0},
#  'masyarakat': {'NN': 1.0},
#  'menganggap': {'VB': 1.0},
#  'suci': {'JJ': 1.0},
#  'selain': {'CC': 1.0},
#  'harus': {'MD': 1.0},
#  'juga': {'RB': 1.0},
#  'kesulitan': {'VB': 1.0},
#  'mengatasi': {'VB': 1.0},
#  'wabah': {'NN': 1.0},
#  'demam berdarah': {'NN': 1.0},
#  'curah': {'NN': 1.0},
#  'hujan': {'NN': 1.0},
#  'tinggi': {'JJ': 1.0},
#  'menyebabkan': {'VB': 1.0},
#  'banyak': {'CD': 1.0},
#  'genangan': {'NN': 1.0},
#  'tempat': {'NN': 1.0},
#  'ideal': {'JJ': 1.0},
#  'bagi': {'IN': 1.0},
#  'nyamuk': {'NN': 1.0},
#  'aedes': {'NNP': 1.0},
#  'berkembang biak': {'VB': 1.0},
#  'telah': {'MD': 1.0},
#  'menempatkan': {'VB': 1.0},
#  'ikan': {'NN': 1.0},
#  'berbagai': {'CD': 1.0},
#  'air': {'NN': 1.0},
#  'memangsa': {'VB': 1.0},
#  'telur': {'NN': 1.0},
#  'miliarder': {'NN': 1.0},
#  'as': {'NNP': 1.0},
#  'jamu': {'VB': 1.0},
#  'orang kaya': {'NN': 1.0},
#  'cina': {'NNP': 1.0},
#  'amerika': {'NNP': 1.0},
#  'bill': {'NNP': 1.0},
#  'gates': {'NNP': 1.0},
#  'warren': {'NNP': 1.0},
#  'buffett': {'NNP': 1.0},
#  'mengadakan': {'VB': 1.0},
#  'jamuan': {'NN': 1.0},
#  'makan malam': {'NN': 1.0},
#  'beijing': {'NNP': 1.0},
#  'sejumlah': {'CD': 1.0},
#  'orang': {'NN': 0.7777777777777778, 'NND': 0.2222222222222222},
#  'terkaya': {'JJ': 1.0},
#  'mengatakan': {'VB': 1.0},
#  'mempelajari': {'VB': 1.0},
#  'kegiatan': {'NN': 1.0},
#  'amal': {'NN': 1.0},
#  'negara': {'NN': 1.0},
#  'itu': {'PR': 1.0},
#  'menduga': {'VB': 1.0},
#  'ingin': {'RB': 1.0},
#  'membujuk': {'VB': 1.0},
#  'para': {'DT': 1.0},
#  'tamu': {'NN': 1.0},
#  'agar': {'SC': 1.0},
#  'menyumbang': {'VB': 1.0},
#  'kedua': {'CD': 1.0},
#  'dunia': {'NN': 1.0},
#  'sudah': {'MD': 1.0},
#  'berhasil': {'VB': 1.0},
#  'sangat': {'RB': 1.0},
#  'kaya': {'JJ': 1.0},
#  'menyumbangkan': {'VB': 1.0},
#  'separuh': {'CD': 1.0},
#  'kekayaan': {'NN': 1.0},
#  'ada': {'VB': 1.0},
#  'kerahasiaan': {'NN': 1.0},
#  'mengenai': {'IN': 0.75, 'SC': 0.25},
#  'acara': {'NN': 1.0},
#  'pihak': {'NN': 1.0},
#  'penyelenggara': {'NN': 1.0},
#  'membeberkan': {'VB': 1.0},
#  'nama-nama': {'NN': 1.0},
#  'salah satu': {'CD': 1.0},
#  'menghadiri': {'VB': 1.0},
#  'adalah': {'VB': 1.0},
#  'chen': {'NNP': 1.0},
#  'guangbiao': {'NNP': 1.0},
#  'seorang': {'NND': 1.0},
#  'meraup': {'VB': 1.0},
#  'bisnis': {'NN': 1.0},
#  'mendaur ulang': {'VB': 1.0},
#  'sampah': {'NN': 1.0},
#  'industri': {'NN': 1.0},
#  'bangunan': {'NN': 1.0},
#  'dia': {'PRP': 1.0},
#  'bbc': {'NNP': 1.0},
#  'bahwa': {'SC': 1.0},
#  'seluruh': {'CD': 1.0},
#  'harta': {'NN': 1.0},
#  '-nya': {'PRP': 1.0},
#  'bila': {'SC': 1.0},
#  'meninggal': {'VB': 1.0},
#  '\tz\r\nberamal\tvb\r\ndan\tcc\r\nmembantu\tvb\r\nsudah\tmd\r\nmenjadi\tvb\r\nbagian\tnn\r\ndari\tin\r\nbudaya\tnn\r\ncina\tnnp\r\nselama\tin\r\n5.000\tcd\r\ntahun\tnn\r\n.\tz\r\n\r\ntetapi\tcc\r\nkegiatan\tnn\r\namal\tnn\r\nresmi\tjj\r\nbaru\tmd\r\ndikembangkan\tvb\r\ndi\tin\r\ncina\tnnp\r\ndalam\tin\r\n30\tcd\r\ntahun\tnn\r\nterakhir\tjj\r\n,\tz\r\nsejak\tsc\r\nkami\tprp\r\nmenerapkan\tvb\r\nreformasi ekonomi\tnn\r\n.\tz\r\n': {'Z': 1.0},
#  '\tz\r\nbanyak\tcd\r\norang\tnn\r\nbaru\tmd\r\nmulai\tmd\r\nmenjadi\tvb\r\nkaya\tjj\r\ndan\tcc\r\nkami\tprp\r\nbaru-baru ini\trb\r\nsaja\trb\r\nbisa\tmd\r\nmemberi\tvb\r\nmakan\tnn\r\ndiri\tnn\r\nsendiri\tnn\r\n,\tz\r\n': {'Z': 1.0},
#  'uang': {'NN': 1.0},
#  'berkembang': {'VB': 1.0},
#  'sebaik': {'JJ': 1.0},
#  'kalau': {'SC': 1.0},
#  'dikatakan': {'VB': 1.0},
#  'keberhasilan': {'NN': 1.0},
#  'mendorong': {'VB': 1.0},
#  'perdebatan': {'NN': 1.0},
#  'apa': {'SC': 1.0},
#  'arti': {'NN': 1.0},
#  'beramal': {'VB': 1.0},
#  'membutuhkan': {'VB': 1.0},
#  'kisah': {'NN': 1.0},
#  'pendiri': {'NN': 1.0},
#  'facebook': {'NNP': 1.0},
#  'dibuat': {'VB': 1.0},
#  'komik': {'NN': 1.0},
#  'mark': {'NNP': 1.0},
#  'zuckerberg': {'NNP': 1.0},
#  'diceritakan': {'VB': 1.0},
#  'dalam': {'IN': 0.875, 'NN': 0.125},
#  'sebuah': {'NND': 1.0},
#  'biografi': {'NN': 1.0},
#  'judul': {'NN': 1.0},
#  ':': {'Z': 1.0},
#  'pencipta': {'NN': 1.0},
#  'tersedia': {'VB': 1.0},
#  'pasar': {'NN': 1.0},
#  'sebelum': {'SC': 1.0},
#  'desember': {'NNP': 1.0},
#  '2010': {'CD': 1.0},
#  'demikian': {'PR': 1.0},
#  'pernyataan': {'NN': 1.0},
#  'penerbit': {'NNP': 1.0},
#  'bluewater': {'NNP': 1.0},
#  'productions': {'NNP': 1.0},
#  'penulis': {'NNP': 1.0},
#  'jerome': {'NNP': 1.0},
#  'maida': {'NNP': 1.0},
#  'menyebut': {'VB': 1.0},
#  '\tz\r\nmengagumkan\tvb\r\n': {'Z': 1.0},
#  '\tz\r\nluar biasa\tjj\r\n': {'Z': 1.0},
#  'film': {'NN': 1.0},
#  'the': {'NNP': 1.0},
#  'social': {'NNP': 1.0},
#  'network': {'NNP': 1.0},
#  'dirilis': {'VB': 1.0},
#  'pada': {'IN': 1.0},
#  'tanggal': {'NN': 1.0},
#  '15': {'CD': 1.0},
#  'oktober': {'NNP': 1.0},
#  'nanti': {'NN': 1.0},
#  'ditulis': {'VB': 1.0},
#  'oleh': {'IN': 1.0},
#  'serial': {'NN': 1.0},
#  'west': {'NNP': 1.0},
#  'wing': {'NNP': 1.0},
#  'aaron': {'NNP': 1.0},
#  'sorkin': {'NNP': 1.0},
#  'disutradarai': {'VB': 1.0},
#  'david': {'NNP': 1.0},
#  'fincher': {'NNP': 1.0},
#  'pernah': {'MD': 1.0},
#  'menggarap': {'VB': 1.0},
#  'fight': {'NNP': 1.0},
#  "'": {'NNP': 1.0},
#  's': {'NNP': 1.0},
#  'club': {'NNP': 1.0},
#  'sebenarnya': {'RB': 1.0},
#  'memperoleh': {'VB': 1.0},
#  'izin': {'NN': 1.0},
#  'pemuda': {'NN': 1.0},
#  'berusia': {'VB': 1.0},
#  '26': {'CD': 1.0},
#  'tahun': {'NN': 1.0},
#  '\tz\r\nsaya\tprp\r\nmengharapkan\tvb\r\ntidak\tneg\r\nada\tvb\r\norang\tnn\r\nyang\tsc\r\nmembuat\tvb\r\nfilm\tnn\r\ntentang\tin\r\nsaya\tprp\r\nketika\tsc\r\nsaya\tprp\r\nmasih\tmd\r\nhidup\tvb\r\n,\tz\r\n': {'Z': 1.0},
#  'konferensi': {'NN': 1.0},
#  'teknologi': {'NN': 1.0},
#  'juni': {'NNP': 1.0},
#  'silam': {'NN': 1.0},
#  'hingga': {'IN': 1.0},
#  'juli': {'NNP': 1.0},
#  '500': {'CD': 1.0},
#  'juta': {'CD': 1.0},
#  'terdaftar': {'VB': 1.0},
#  'situs': {'NN': 1.0},
#  'jejaring': {'NN': 1.0},
#  'sosial': {'JJ': 1.0},
#  'tersebut': {'PR': 1.0},
#  'hanya': {'RB': 1.0},
#  'butuh': {'VB': 1.0},
#  'enam': {'CD': 1.0},
#  'kesuksesan': {'NN': 1.0},
#  'seperti': {'SC': 0.5, 'IN': 0.5},
#  'sekarang': {'NN': 1.0},
#  'setelah': {'SC': 1.0},
#  'meluncurkan': {'VB': 1.0},
#  'saat': {'SC': 1.0},
#  'masih': {'MD': 1.0},
#  'duduk': {'VB': 1.0},
#  'sebagai': {'IN': 1.0},
#  'mahasiswa': {'NN': 1.0},
#  'universitas': {'NNP': 1.0},
#  'harvard': {'NNP': 1.0},
#  'september': {'NNP': 1.0},
#  'majalah': {'NNP': 1.0},
#  'forbes': {'NNP': 1.0},
#  'memasukkan': {'VB': 1.0},
#  'daftar': {'NN': 1.0},
#  '35': {'CD': 1.0},
#  'serikat': {'NNP': 1.0},
#  'total': {'NN': 1.0},
#  'diperkirakan': {'VB': 1.0},
#  'us': {'NNP': 1.0},
#  '$': {'SYM': 1.0},
#  '6,4': {'CD': 1.0},
#  'miliar': {'CD': 1.0},
#  'tetapi': {'CC': 1.0},
#  'langkah': {'NN': 1.0},
#  'menuju': {'VB': 1.0},
#  'lah': {'RP': 1.0},
#  'mulus': {'JJ': 1.0},
#  'rekan': {'NN': 1.0},
#  'mengklaim': {'VB': 1.0},
#  'ide': {'NN': 1.0},
#  'pembuatan': {'NN': 1.0},
#  'datang': {'VB': 1.0},
#  'terlibat': {'VB': 1.0},
#  'sengketa': {'NN': 1.0},
#  'hukum': {'NN': 1.0},
#  'berlarut-larut': {'VB': 1.0},
#  '2008': {'CD': 1.0},
#  'diakhiri': {'VB': 1.0},
#  'pembayaran': {'NN': 1.0},
#  'dirahasiakan': {'VB': 1.0},
#  'cameron': {'NNP': 1.0},
#  'tyler': {'NNP': 1.0},
#  'winklevoss': {'NNP': 1.0},
#  'kini': {'NN': 1.0},
#  'membuat': {'VB': 1.0},
#  'bernama': {'VB': 1.0},
#  'connectu': {'NNP': 1.0},
#  'perebutan': {'NN': 1.0},
#  'jamrud': {'NNP': 0.375, 'NN': 0.625},
#  'bahia': {'NNP': 1.0},
#  'raksasa': {'JJ': 1.0},
#  'jaksa': {'NN': 1.0},
#  'kalifornia': {'NNP': 1.0},
#  'mulai': {'MD': 1.0},
#  'menanyai': {'VB': 1.0},
#  'menentukan': {'VB': 1.0},
#  'kepemilikan': {'NN': 1.0},
#  'disebut': {'VB': 1.0},
#  'terbesar': {'JJ': 1.0},
#  'dinamakan': {'VB': 1.0},
#  'sesuai': {'JJ': 1.0},
#  'lokasi': {'NN': 1.0},
#  'penemuan': {'NN': 1.0},
#  'daerah': {'NN': 1.0},
#  'brasil': {'NNP': 1.0},
#  'berat': {'NN': 1.0},
#  '380': {'CD': 1.0},
#  'kg': {'NND': 1.0},
#  'bernilai': {'VB': 1.0},
#  '370': {'CD': 1.0},
#  'hak': {'NN': 1.0},
#  'atas': {'IN': 1.0},
#  'batu': {'NN': 1.0},
#  'mendengarkan': {'VB': 1.0},
#  'semua': {'CD': 1.0},
#  'permata': {'NN': 1.0},
#  'memutuskan': {'VB': 1.0},
#  'kasus': {'NN': 1.0},
#  'berselisih': {'VB': 1.0},
#  'anthony': {'NNP': 1.0},
#  'thomas': {'NNP': 1.0},
#  'ahli': {'NN': 1.0},
#  'konstruksi': {'NN': 1.0},
#  'membayar': {'VB': 1.0},
#  'agen': {'NN': 1.0},
#  'senilai': {'NN': 1.0},
#  '60.000': {'CD': 1.0},
#  'tak': {'NEG': 1.0},
#  'ditemukan': {'VB': 1.0},
#  'sembilan': {'CD': 1.0},
#  'lalu': {'NN': 1.0},
#  'mengatur': {'VB': 1.0},
#  'dikirim': {'VB': 1.0},
#  'melalui': {'IN': 1.0},
#  'kapal': {'NN': 1.0},
#  'ke': {'IN': 1.0},
#  'kediaman': {'NN': 1.0},
#  'san': {'NNP': 1.0},
#  'jose': {'NNP': 1.0},
#  'muncul': {'VB': 1.0},
#  'percaya': {'VB': 1.0},
#  'dicuri': {'VB': 1.0},
#  'dijual': {'VB': 1.0},
#  'kembali': {'RB': 1.0},
#  'harga': {'NN': 1.0},
#  'mahal': {'JJ': 1.0},
#  'pemilik': {'NN': 1.0},
#  'satu': {'CD': 1.0},
#  'masalah': {'NN': 1.0},
#  'dihadapi': {'VB': 1.0},
#  'kehilangan': {'VB': 1.0},
#  'tanda terima': {'NN': 1.0},
#  'akibat': {'IN': 1.0},
#  'kebakaran': {'NN': 1.0},
#  'melanda': {'VB': 1.0},
#  'rumah': {'NN': 1.0},
#  'akhirnya': {'RB': 1.0},
#  'sampai': {'VB': 1.0},
#  'meskipun': {'SC': 1.0},
#  'setibanya': {'SC': 1.0},
#  'jelas': {'JJ': 1.0},
#  'siapa': {'SC': 1.0},
#  'hal': {'NN': 1.0},
#  'diketahui': {'VB': 1.0},
#  'sempat': {'MD': 1.0},
#  'disimpan': {'VB': 1.0},
#  'lemari besi': {'NN': 1.0},
#  'bank': {'NN': 1.0},
#  'new': {'NNP': 1.0},
#  'orleans': {'NNP': 1.0},
#  'terkena': {'VB': 1.0},
#  'banjir': {'NN': 1.0},
#  'ketika': {'SC': 1.0},
#  'diterjang': {'VB': 1.0},
#  'badai': {'NNP': 1.0},
#  'katrina': {'NNP': 1.0},
#  'sehingga': {'SC': 1.0},
#  'berharga': {'JJ': 1.0},
#  'terendam': {'VB': 1.0},
#  'bulan': {'NN': 1.0},
#  'kemudian': {'RB': 1.0},
#  'dibawa': {'VB': 1.0},
#  'las': {'NNP': 1.0},
#  'vegas': {'NNP': 1.0},
#  'dilihat': {'VB': 1.0},
#  'calon': {'NN': 1.0},
#  'pembeli': {'NN': 1.0},
#  'namun': {'CC': 1.0},
#  'disita': {'VB': 1.0},
#  'polisi': {'NN': 1.0},
#  'los': {'NNP': 1.0},
#  'angeles': {'NNP': 1.0},
#  'badut': {'NN': 1.0},
#  'politikus': {'NN': 1.0},
#  'ditantang': {'VB': 1.0},
#  'baca': {'VB': 1.0},
#  'tulis': {'VB': 1.0},
#  'mempunyai': {'VB': 1.0},
#  'peluang': {'NN': 1.0},
#  'meraih': {'VB': 1.0},
#  'kursi': {'NN': 1.0},
#  'pemilihan': {'NN': 1.0},
#  'minggu': {'NNP': 1.0},
#  '(': {'Z': 1.0},
#  '3': {'CD': 1.0},
#  '/': {'Z': 1.0},
#  ')': {'Z': 1.0},
#  '-': {'Z': 1.0},
#  'membuktikan': {'VB': 1.0},
#  'membaca': {'VB': 1.0},
#  'menulis': {'VB': 1.0},
#  'jajak': {'NN': 1.0},
#  'pendapat': {'NN': 1.0},
#  'memperlihatkan': {'VB': 1.0},
#  'tiririca': {'NNP': 1.0},
#  'suara': {'NN': 1.0},
#  'hakim': {'NN': 1.0},
#  'sao': {'NNP': 1.0},
#  'paulo': {'NNP': 1.0},
#  'menuntut': {'VB': 1.0},
#  'memenuhi': {'VB': 1.0},
#  'persyaratan': {'NN': 1.0},
#  'surat kabar': {'NN': 1.0},
#  'sama': {'JJ': 1.0},
#  'sepuluh': {'CD': 1.0},
#  'buta aksara': {'JJ': 1.0}}
